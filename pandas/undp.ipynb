# %%
import numpy as np
import pandas as pd

# %%
project = pd.read_csv('/Users/mt/Desktop/undp/UNDP Project Data.csv')
project.head(5)
# Out:
#   Country CreatedBy       Country CreatedOn  \
# 0    RES01\admcunat  11/23/2016 10:30:50 AM
# 1    RES01\admcunat  11/23/2016 10:30:50 AM
# 2    RES01\admcunat  11/23/2016 10:30:50 AM
# 3    RES01\admcunat  11/23/2016 10:30:50 AM
# 4    RES01\admcunat  11/23/2016 10:30:50 AM
#
#                       Country ECHORegion Country ISO  Country Key  \
# 0  Caucasus & EU's Eastern Neighbourhood         ARM          120
# 1  Caucasus & EU's Eastern Neighbourhood         ARM          120
# 2  Caucasus & EU's Eastern Neighbourhood         ARM          120
# 3  Caucasus & EU's Eastern Neighbourhood         ARM          120
# 4  Caucasus & EU's Eastern Neighbourhood         ARM          120
#
#    Country Latitude  Country Longitude Country Name Country Name Short  \
# 0           40.1596             44.509      Armenia            Armenia
# 1           40.1596             44.509      Armenia            Armenia
# 2           40.1596             44.509      Armenia            Armenia
# ...

# %%
violence = pd.read_csv('/Users/mt/Desktop/undp/ACLED Political Violence.csv')
violence.head(5)
